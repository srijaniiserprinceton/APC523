# %% [markdown]
# The issue with polynomial roots:

# %%
import numpy as np

roots = np.arange(1,21)  #initializing the roots from 1-20

coeffs = np.poly(roots) #array of coefficients in decending powers
coeffs_der = np.flip(roots)*coeffs[0:20] #constructing coefficients for derivative of polynomial

f = np.poly1d(coeffs)  #constructing the callable polynomial function
f_der = np.poly1d(coeffs_der) #constructing the callable polynomial derivative function

eps = 1e-1
x0 = 13.58
diff = abs(f(x0))
counter = 1

print(coeffs)

while(diff > eps):
    x_new = x0 - (f(x0)/f_der(x0))
    diff = abs(f(x_new))
    x0 = x_new
    counter += 1
    if(counter > 100): break

print(x0)
# Out:
# [ 1.00000000e+00 -2.10000000e+02  2.06150000e+04 -1.25685000e+06
#   5.33279460e+07 -1.67228082e+09  4.01717716e+10 -7.56111184e+11
#   1.13102770e+13 -1.35585183e+14  1.30753501e+15 -1.01422999e+16
#   6.30308121e+16 -3.11333643e+17  1.20664780e+18 -3.59997952e+18
#   8.03781182e+18 -1.28709312e+19  1.38037598e+19 -8.75294804e+18
#   2.43290201e+18]
# 19.99997540345901

# %%
abs(f(x0))
# Out:
# 352026405888.0

# %%
x0
# Out:
# 19.99997540345901

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
x = np.linspace(7,13,10000)
plt.plot(x,f(x))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f((f.roots)[0])
# Out:
# -16717232513536.0

# %%
f.roots
# Out:
# array([19.99987406, 19.00129539, 17.99367156, 17.01854165, 15.95971757,
#        15.05932623, 13.93018645, 13.06266365, 11.958874  , 11.02246427,
#         9.99119095,  9.00271274,  7.99939431,  7.00009695,  5.99998952,
#         5.00000071,  3.99999997,  3.        ,  2.        ,  1.        ])

# %%
f(20)
# Out:
# -27029504000.0

# %%
f_der(1)
# Out:
# -1.216451004088279e+17
